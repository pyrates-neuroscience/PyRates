# %%
# pyrates imports
from pyrates.ir.circuit import CircuitIR
from pyrates.backend import ComputeGraph
from pyrates.utility import plot_connectivity, create_cmap
from pyrates.frontend import CircuitTemplate

# additional imports
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.reload_library()
plt.style.use('ggplot')
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.labelsize'] = 24
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['axes.labelweight'] = 'bold'
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['xtick.color'] = 'black'
mpl.rcParams['ytick.color'] = 'black'
mpl.rcParams['legend.fontsize'] = 20
from copy import deepcopy

# %matplotlib inline

# %% [markdown]
# PyRates Benchmark Simulations
# =============================
#
# Below, you will find the code to run the benchmarks described in detail in "Gast, R. et al. (2018) PyRates - A Python framework for neural modeling and simulations on parallel hardware". These benchmarks consist of numerical simulations of neural population networks that differ in size and coupling density.
#
# Benchmark parameters
# --------------------
#
# In the cell below, all important parameters of the subsequent benchmark simulations are defined.

# %%
dt = 1e-3                                       # integration step-size of the forward euler solver in s
T = 1.0                                         # simulation time in s
c = 20.                                         # global connection strength scaling
N =[1, 10, 100][::-1]                           # network sizes, each of which will be run a benchmark for
p = [0.81, 0.27, 0.09, 0.03, 0.01][::-1]        # global coupling probabilities, each of which will be run a benchmark for

# %%
def benchmark(Ns, Ps, T, dt, init_kwargs, run_kwargs):
    """Function that will run a benchmark simulation for each combination of N and P. 
    Each benchmark simulation simulates the behavior of a neural population network, where the Jansen-Rit model is used for each of the N nodes and 
    connections are drawn randomly, such that on overall coupling density of P is established.

    Parameters
    ----------
    Ns
        Vector with network sizes.
    Ps
        Vector with coupling densities.
    T
        Overall simulation time.
    dt
        Integration step-size.
    init_kwargs
        Additional key-word arguments for the model initialization.
    run_kwargs
        Additional key-word arguments for running the simulation.

    Returns
    -------
    tuple
        Simulation times, peak memory consumptions

    """

    times = np.zeros((len(Ns), len(Ps)))
    peak_mem = np.zeros_like(times)

    for i, n in enumerate(Ns):
        for j, p in enumerate(Ps):

            print(f'Running benchmark for n = {n} and p = {p}.')
            print("Setting up the network in PyRates...")
            
            # define inter-JRC connectivity
            C = np.random.uniform(size=(n, n))
            C[C > p] = 0.
            conns = DataFrame(C, columns=[f'jrc_{idx}/PC.0/PRO.0/m_out' for idx in range(n)])
            conns.index = [f'jrc_{idx}/PC.0/RPO_e_pc.0/m_in' for idx in range(n)]

            # define input
            inp = 220 + np.random.randn(int(T / dt), n) * 22.

            # set up template
            template = CircuitTemplate.from_yaml("pyrates.examples.jansen_rit.simple_jr.JRC")

            # set up intermediate representation
            circuits = {}
            for idx in range(n):
                circuits[f'jrc_{idx}'] = deepcopy(template)
            circuit = CircuitIR.from_circuits(label='net', circuits=circuits, connectivity=conns)

            # set up compute graph
            net = ComputeGraph(circuit, dt=dt, **init_kwargs)
            
            print("Starting the benchmark simulation...")
            
            # run simulations
            _, t, m = net.run(T, inputs={('PC', 'RPO_e_pc.0', 'u'): inp}, outputs={'V': ('PC', 'PRO.0', 'PSP')},
                              verbose=False, **run_kwargs)
            times[i, j] = t
            peak_mem[i, j] = m
            
            print("Finished!")
            
    return times, peak_mem

# %%
results = np.zeros((len(N), len(p), 3))                       # array in which results will be stored

t, m = benchmark(N, p, T, dt, 
                 init_kwargs={'vectorization': 'full'}, 
                 run_kwargs={'profile': 'mt'})                # runs benchmark function on GPU
results[:, :, 0] = t
results[:, :, 1] = m

t, _ = benchmark(N, p, T, dt,                                 # runs benchmark function on CPU
                 init_kwargs={'vectorization': 'full'}, 
                 run_kwargs={'profile': 't'})
results[:, :, 3] = t
# Out:
# Running benchmark for n = 100 and p = 0.01.
# connectivity setup
# ...finished after 0.0013494491577148438 seconds.
# Frontend template setup
# ...finished after 5.984306335449219e-05 seconds.
# IR setup
# ...finished after 0.23457717895507812 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.51202392578125 seconds.
# ...finished after 0.8812777996063232 seconds.
# Running benchmark for n = 100 and p = 0.03.
# connectivity setup
# ...finished after 0.0007715225219726562 seconds.
# Frontend template setup
# ...finished after 3.075599670410156e-05 seconds.
# IR setup
# ...finished after 0.23082685470581055 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.5408420562744141 seconds.
# ...finished after 1.1210064888000488 seconds.
# Running benchmark for n = 100 and p = 0.09.
# connectivity setup
# ...finished after 0.0007162094116210938 seconds.
# Frontend template setup
# ...finished after 3.1948089599609375e-05 seconds.
# IR setup
# ...finished after 0.24164819717407227 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.647982120513916 seconds.
# ...finished after 1.1913113594055176 seconds.
# Running benchmark for n = 100 and p = 0.27.
# connectivity setup
# ...finished after 0.000885009765625 seconds.
# Frontend template setup
# ...finished after 4.267692565917969e-05 seconds.
# IR setup
# ...finished after 0.4008147716522217 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.7611901760101318 seconds.
# ...finished after 1.4863412380218506 seconds.
# Running benchmark for n = 100 and p = 0.81.
# connectivity setup
# ...finished after 0.001055002212524414 seconds.
# Frontend template setup
# ...finished after 3.6716461181640625e-05 seconds.
# IR setup
# ...finished after 0.39934611320495605 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.8122541904449463 seconds.
# ...finished after 1.3581910133361816 seconds.
# Running benchmark for n = 10 and p = 0.01.
# connectivity setup
# ...finished after 0.0007567405700683594 seconds.
# Frontend template setup
# ...finished after 3.3855438232421875e-05 seconds.
# IR setup
# ...finished after 0.027341842651367188 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.018074989318847656 seconds.
# ...finished after 0.4090275764465332 seconds.
# Running benchmark for n = 10 and p = 0.03.
# connectivity setup
# ...finished after 0.0008087158203125 seconds.
# Frontend template setup
# ...finished after 3.5762786865234375e-05 seconds.
# IR setup
# ...finished after 0.029466629028320312 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.01877307891845703 seconds.
# ...finished after 0.6552770137786865 seconds.
# Running benchmark for n = 10 and p = 0.09.
# connectivity setup
# ...finished after 0.0007886886596679688 seconds.
# Frontend template setup
# ...finished after 5.650520324707031e-05 seconds.
# IR setup
# ...finished after 0.028769969940185547 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.01970505714416504 seconds.
# ...finished after 0.41538214683532715 seconds.
# Running benchmark for n = 10 and p = 0.27.
# connectivity setup
# ...finished after 0.0007450580596923828 seconds.
# Frontend template setup
# ...finished after 3.552436828613281e-05 seconds.
# IR setup
# ...finished after 0.029783964157104492 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.01958155632019043 seconds.
# ...finished after 0.4267458915710449 seconds.
# Running benchmark for n = 10 and p = 0.81.
# connectivity setup
# ...finished after 0.0007512569427490234 seconds.
# Frontend template setup
# ...finished after 3.528594970703125e-05 seconds.
# IR setup
# ...finished after 0.0316615104675293 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.020212650299072266 seconds.
# ...finished after 0.4260108470916748 seconds.
# Running benchmark for n = 1 and p = 0.01.
# connectivity setup
# ...finished after 0.0007596015930175781 seconds.
# Frontend template setup
# ...finished after 3.6716461181640625e-05 seconds.
# IR setup
# ...finished after 0.0033643245697021484 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0023670196533203125 seconds.
# ...finished after 0.579763650894165 seconds.
# Running benchmark for n = 1 and p = 0.03.
# connectivity setup
# ...finished after 0.0007164478302001953 seconds.
# Frontend template setup
# ...finished after 3.3855438232421875e-05 seconds.
# IR setup
# ...finished after 0.003201723098754883 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.002173185348510742 seconds.
# ...finished after 0.34978246688842773 seconds.
# Running benchmark for n = 1 and p = 0.09.
# connectivity setup
# ...finished after 0.0007493495941162109 seconds.
# Frontend template setup
# ...finished after 3.62396240234375e-05 seconds.
# IR setup
# ...finished after 0.0032989978790283203 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0023598670959472656 seconds.
# ...finished after 0.3546004295349121 seconds.
# Running benchmark for n = 1 and p = 0.27.
# connectivity setup
# ...finished after 0.0008127689361572266 seconds.
# Frontend template setup
# ...finished after 3.790855407714844e-05 seconds.
# IR setup
# ...finished after 0.003269672393798828 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0023565292358398438 seconds.
# ...finished after 0.34587955474853516 seconds.
# Running benchmark for n = 1 and p = 0.81.
# connectivity setup
# ...finished after 0.0005650520324707031 seconds.
# Frontend template setup
# ...finished after 3.62396240234375e-05 seconds.
# IR setup
# ...finished after 0.0032732486724853516 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0022611618041992188 seconds.
# ...finished after 0.59413743019104 seconds.
# Running benchmark for n = 100 and p = 0.01.
# connectivity setup
# ...finished after 0.0008459091186523438 seconds.
# Frontend template setup
# ...finished after 3.528594970703125e-05 seconds.
# IR setup
# ...finished after 0.27450132369995117 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.7167127132415771 seconds.
# ...finished after 1.037851333618164 seconds.
# Running benchmark for n = 100 and p = 0.03.
# connectivity setup
# ...finished after 0.0011255741119384766 seconds.
# Frontend template setup
# ...finished after 3.981590270996094e-05 seconds.
# IR setup
# ...finished after 0.28108978271484375 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.705960750579834 seconds.
# ...finished after 1.0369513034820557 seconds.
# Running benchmark for n = 100 and p = 0.09.
# connectivity setup
# ...finished after 0.0009634494781494141 seconds.
# Frontend template setup
# ...finished after 3.7670135498046875e-05 seconds.
# IR setup
# ...finished after 0.2897493839263916 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.7105042934417725 seconds.
# ...finished after 1.2444627285003662 seconds.
# Running benchmark for n = 100 and p = 0.27.
# connectivity setup
# ...finished after 0.0008831024169921875 seconds.
# Frontend template setup
# ...finished after 3.6716461181640625e-05 seconds.
# IR setup
# ...finished after 0.31781864166259766 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.7449393272399902 seconds.
# ...finished after 1.083223819732666 seconds.
# Running benchmark for n = 100 and p = 0.81.
# connectivity setup
# ...finished after 0.0009169578552246094 seconds.
# Frontend template setup
# ...finished after 3.695487976074219e-05 seconds.
# IR setup
# ...finished after 0.39157652854919434 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.8504068851470947 seconds.
# ...finished after 1.424910306930542 seconds.
# Running benchmark for n = 10 and p = 0.01.
# connectivity setup
# ...finished after 0.0005452632904052734 seconds.
# Frontend template setup
# ...finished after 3.337860107421875e-05 seconds.
# IR setup
# ...finished after 0.03066420555114746 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.020491361618041992 seconds.
# ...finished after 0.33110690116882324 seconds.
# Running benchmark for n = 10 and p = 0.03.
# connectivity setup
# ...finished after 0.0008003711700439453 seconds.
# Frontend template setup
# ...finished after 3.8623809814453125e-05 seconds.
# IR setup
# ...finished after 0.029485702514648438 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.02143573760986328 seconds.
# ...finished after 0.3392353057861328 seconds.
# Running benchmark for n = 10 and p = 0.09.
# connectivity setup
# ...finished after 0.0007886886596679688 seconds.
# Frontend template setup
# ...finished after 3.5762786865234375e-05 seconds.
# IR setup
# ...finished after 0.029590129852294922 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.02237081527709961 seconds.
# ...finished after 0.3413670063018799 seconds.
# Running benchmark for n = 10 and p = 0.27.
# connectivity setup
# ...finished after 0.0005614757537841797 seconds.
# Frontend template setup
# ...finished after 3.647804260253906e-05 seconds.
# IR setup
# ...finished after 0.029932022094726562 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.021446943283081055 seconds.
# ...finished after 0.5625197887420654 seconds.
# Running benchmark for n = 10 and p = 0.81.
# connectivity setup
# ...finished after 0.0008480548858642578 seconds.
# Frontend template setup
# ...finished after 3.7670135498046875e-05 seconds.
# IR setup
# ...finished after 0.029959917068481445 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.023624420166015625 seconds.
# ...finished after 0.3487396240234375 seconds.
# Running benchmark for n = 1 and p = 0.01.
# connectivity setup
# ...finished after 0.0005409717559814453 seconds.
# Frontend template setup
# ...finished after 3.314018249511719e-05 seconds.
# IR setup
# ...finished after 0.0032470226287841797 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0033140182495117188 seconds.
# ...finished after 0.3208622932434082 seconds.
# Running benchmark for n = 1 and p = 0.03.
# connectivity setup
# ...finished after 0.0007123947143554688 seconds.
# Frontend template setup
# ...finished after 3.647804260253906e-05 seconds.
# IR setup
# ...finished after 0.003279447555541992 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0034127235412597656 seconds.
# ...finished after 0.3243370056152344 seconds.
# Running benchmark for n = 1 and p = 0.09.
# connectivity setup
# ...finished after 0.0007755756378173828 seconds.
# Frontend template setup
# ...finished after 3.4809112548828125e-05 seconds.
# IR setup
# ...finished after 0.0032720565795898438 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0034334659576416016 seconds.
# ...finished after 0.3205726146697998 seconds.
# Running benchmark for n = 1 and p = 0.27.
# connectivity setup
# ...finished after 0.0007197856903076172 seconds.
# Frontend template setup
# ...finished after 3.528594970703125e-05 seconds.
# IR setup
# ...finished after 0.003301382064819336 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0034592151641845703 seconds.
# ...finished after 0.534745454788208 seconds.
# Running benchmark for n = 1 and p = 0.81.
# connectivity setup
# ...finished after 0.0005705356597900391 seconds.
# Frontend template setup
# ...finished after 3.314018249511719e-05 seconds.
# IR setup
# ...finished after 0.003335714340209961 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0034332275390625 seconds.
# ...finished after 0.32006001472473145 seconds.
# Running benchmark for n = 100 and p = 0.01.
# connectivity setup
# ...finished after 0.0009968280792236328 seconds.
# Frontend template setup
# ...finished after 4.00543212890625e-05 seconds.
# IR setup
# ...finished after 0.27936744689941406 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.6962759494781494 seconds.
# ...finished after 1.0237174034118652 seconds.
# Running benchmark for n = 100 and p = 0.03.
# connectivity setup
# ...finished after 0.0008828639984130859 seconds.
# Frontend template setup
# ...finished after 6.532669067382812e-05 seconds.
# IR setup
# ...finished after 0.27036309242248535 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.9207215309143066 seconds.
# ...finished after 1.2433586120605469 seconds.
# Running benchmark for n = 100 and p = 0.09.
# connectivity setup
# ...finished after 0.0009353160858154297 seconds.
# Frontend template setup
# ...finished after 6.389617919921875e-05 seconds.
# IR setup
# ...finished after 0.2838010787963867 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.713294267654419 seconds.
# ...finished after 1.0481736660003662 seconds.
# Running benchmark for n = 100 and p = 0.27.
# connectivity setup
# ...finished after 0.0008571147918701172 seconds.
# Frontend template setup
# ...finished after 6.437301635742188e-05 seconds.
# IR setup
# ...finished after 0.3069899082183838 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.7452189922332764 seconds.
# ...finished after 1.3015832901000977 seconds.
# Running benchmark for n = 100 and p = 0.81.
# connectivity setup
# ...finished after 0.0011036396026611328 seconds.
# Frontend template setup
# ...finished after 5.125999450683594e-05 seconds.
# IR setup
# ...finished after 0.3807528018951416 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.853320837020874 seconds.
# ...finished after 1.246330738067627 seconds.
# Running benchmark for n = 10 and p = 0.01.
# connectivity setup
# ...finished after 0.0006525516510009766 seconds.
# Frontend template setup
# ...finished after 3.695487976074219e-05 seconds.
# IR setup
# ...finished after 0.027868270874023438 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0200502872467041 seconds.
# ...finished after 0.33372020721435547 seconds.
# Running benchmark for n = 10 and p = 0.03.
# connectivity setup
# ...finished after 0.0005443096160888672 seconds.
# Frontend template setup
# ...finished after 3.504753112792969e-05 seconds.
# IR setup
# ...finished after 0.028114795684814453 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0210878849029541 seconds.
# ...finished after 0.5401873588562012 seconds.
# Running benchmark for n = 10 and p = 0.09.
# connectivity setup
# ...finished after 0.0005362033843994141 seconds.
# Frontend template setup
# ...finished after 3.504753112792969e-05 seconds.
# IR setup
# ...finished after 0.029050111770629883 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.021363496780395508 seconds.
# ...finished after 0.3349947929382324 seconds.
# Running benchmark for n = 10 and p = 0.27.
# connectivity setup
# ...finished after 0.0005388259887695312 seconds.
# Frontend template setup
# ...finished after 3.504753112792969e-05 seconds.
# IR setup
# ...finished after 0.03007364273071289 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.02111959457397461 seconds.
# ...finished after 0.3290519714355469 seconds.
# Running benchmark for n = 10 and p = 0.81.
# connectivity setup
# ...finished after 0.0008232593536376953 seconds.
# Frontend template setup
# ...finished after 3.838539123535156e-05 seconds.
# IR setup
# ...finished after 0.029682636260986328 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.022891759872436523 seconds.
# ...finished after 0.3321826457977295 seconds.
# Running benchmark for n = 1 and p = 0.01.
# connectivity setup
# ...finished after 0.0005323886871337891 seconds.
# Frontend template setup
# ...finished after 3.4809112548828125e-05 seconds.
# IR setup
# ...finished after 0.0033309459686279297 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.004100322723388672 seconds.
# ...finished after 0.5429437160491943 seconds.
# Running benchmark for n = 1 and p = 0.03.
# connectivity setup
# ...finished after 0.0005414485931396484 seconds.
# Frontend template setup
# ...finished after 3.337860107421875e-05 seconds.
# IR setup
# ...finished after 0.0037262439727783203 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.003326892852783203 seconds.
# ...finished after 0.3176298141479492 seconds.
# Running benchmark for n = 1 and p = 0.09.
# connectivity setup
# ...finished after 0.0005490779876708984 seconds.
# Frontend template setup
# ...finished after 3.361701965332031e-05 seconds.
# IR setup
# ...finished after 0.0031654834747314453 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.0033659934997558594 seconds.
# ...finished after 0.314985990524292 seconds.
# Running benchmark for n = 1 and p = 0.27.
# connectivity setup
# ...finished after 0.0005357265472412109 seconds.
# Frontend template setup
# ...finished after 3.838539123535156e-05 seconds.
# IR setup
# ...finished after 0.003804922103881836 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.003500699996948242 seconds.
# ...finished after 0.31711673736572266 seconds.
# Running benchmark for n = 1 and p = 0.81.
# connectivity setup
# ...finished after 0.0005252361297607422 seconds.
# Frontend template setup
# ...finished after 4.076957702636719e-05 seconds.
# IR setup
# ...finished after 0.00402069091796875 seconds.
# Compute graph setup
# moving edge operators to nodes...
# checking net config for consistency...
# start of vectorization
# ...finished after 0.003381490707397461 seconds.
# ...finished after 0.5449967384338379 seconds.

# %% [markdown]
# Benchmark results visualization
# -------------------------------
#
# In the first cell below, the colormaps for plotting are defined.
# In the second cell below, heatmaps are created that show the simulation time, peak memory consumption and simulation time difference between GPU and CPU for each combination of network size N and coupling density p.

# %%
# create colormaps
n_colors = 16
cm_red = create_cmap('pyrates_red', as_cmap=True, n=n_colors)
cm_green = create_cmap('pyrates_green', as_cmap=True, n=n_colors)
cm_div = create_cmap('pyrates_blue/pyrates_yellow', as_cmap=True, n=n_colors, reverse=True)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(20, 7))

# plot simulation times of benchmarks run on the GPU
plot_connectivity(results[:, :, 0], ax=axes[0], yticklabels=N, xticklabels=p, cmap=cm_red)
axes[0].set_yticklabels(axes[0].get_yticklabels(), rotation='horizontal')
axes[0].set_ylabel('number of JRCs', labelpad=15.)
axes[0].set_xlabel('coupling density', labelpad=15.)
axes[0].set_title('Simulation time T in s', pad=20.)

# plot memory consumption of benchmarks run on the GPU
plot_connectivity(results[:, :, 1], ax=axes[1], yticklabels=N, xticklabels=p, cmap=cm_green)
axes[1].set_yticklabels(axes[1].get_yticklabels(), rotation='horizontal')
axes[1].set_ylabel('number of JRCs', labelpad=15.)
axes[1].set_xlabel('coupling density', labelpad=15.)
axes[1].set_title('Peak memory in MB', pad=20.)

# plot simulation time differene between GPU and CPU
plot_connectivity(results[:, :, 2] - results[:, :, 0], ax=axes[2], yticklabels=N, xticklabels=p, cmap=cm_div)
axes[2].set_yticklabels(axes[2].get_yticklabels(), rotation='horizontal')
axes[2].set_ylabel('number of JRCs', labelppad=15.)
axes[2].set_xlabel('coupling density', labelpad=15.)
axes[2].set_title(r'$\mathbf{T_{CPU}} - \mathbf{T_{CPU}}$', pad=20.)

plt.tight_layout()
#plt.savefig('/img/Gast_2018_PyRates_benchmarks.svg', format='svg')
